# %% [markdown]
# # Churn Prediction Pipeline\nNotebook scaffold aligned with coursework headings.

# %% [markdown]
# ## 1) Problem framing\nDefine target, objective, constraints, and baseline success metrics.

# %% [markdown]
# ## 2) EDA\nAdd concise plots for class balance, missingness, and leakage checks.

# %% [markdown]
# ## 3) Preparation\nUse train/validation/test discipline and leakage-safe preprocessing.

# %% [markdown]
# ## 4) Modelling\nCompare baseline and modern candidates using reproducible settings.

# %% [markdown]
# ## 5) Fine-tune & Evaluate\nTune selected models and evaluate with robust error analysis.

# %% [markdown]
# ## 6) Final solution\nSummarize final model choice, caveats, and deployment-style model card notes.
